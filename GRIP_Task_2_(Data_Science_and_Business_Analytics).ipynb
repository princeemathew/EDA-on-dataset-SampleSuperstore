# %% [markdown]
# **The Sparks Foundation -Data Science and Business Analytics Internship**
#
# **Task 2 - Perform Exploratory Data Analysis on dataset 'SampleSuperstore'**
#
# **Author: Prince Mathew**
#
# **Batch- January 2022**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
# Let's import to our data and check the basics.
dataset=pd.read_csv('/content/SampleSuperstore.csv')
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %% [markdown]
# **Print first 5 Rows.**

# %%
dataset.head()
# Out:
#         Ship Mode    Segment        Country  ... Quantity Discount    Profit
# 0    Second Class   Consumer  United States  ...        2     0.00   41.9136
# 1    Second Class   Consumer  United States  ...        3     0.00  219.5820
# 2    Second Class  Corporate  United States  ...        2     0.00    6.8714
# 3  Standard Class   Consumer  United States  ...        5     0.45 -383.0310
# 4  Standard Class   Consumer  United States  ...        2     0.20    2.5164
#
# [5 rows x 13 columns]

# %% [markdown]
# **Print last 5 Rows.**

# %%
dataset.tail()
# Out:
#            Ship Mode   Segment        Country  ... Quantity Discount   Profit
# 9989    Second Class  Consumer  United States  ...        3      0.2   4.1028
# 9990  Standard Class  Consumer  United States  ...        2      0.0  15.6332
# 9991  Standard Class  Consumer  United States  ...        2      0.2  19.3932
# 9992  Standard Class  Consumer  United States  ...        4      0.0  13.3200
# 9993    Second Class  Consumer  United States  ...        2      0.0  72.9480
#
# [5 rows x 13 columns]

# %% [markdown]
# **Checking the missing value.**

# %%
dataset.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
# **Finding the total no of null values.**

# %%
print('Total number of null values = ',dataset.isnull().sum().sum())
# Out:
# Total number of null values =  0

# %% [markdown]
# **Summary of the dataset.**

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %% [markdown]
# **Statistical details of the dataset.**

# %%
dataset.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %% [markdown]
# **Shape of the dataset.**

# %%
dataset.shape
# Out:
# (9994, 13)

# %% [markdown]
# **Finding the datatype used in this dataset.**

# %%
dataset.dtypes
# Out:
# Ship Mode        object
# Segment          object
# Country          object
# City             object
# State            object
# Postal Code       int64
# Region           object
# Category         object
# Sub-Category     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object

# %% [markdown]
# **Calling out all the columns in the dataset.**

# %%
dataset.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %% [markdown]
# **Checking for the duplicate value and dropping it if necessary.**

# %%
dataset.duplicated().sum()
# Out:
# 17

# %%
dataset.drop_duplicates()
# Out:
#            Ship Mode    Segment        Country  ... Quantity Discount    Profit
# 0       Second Class   Consumer  United States  ...        2     0.00   41.9136
# 1       Second Class   Consumer  United States  ...        3     0.00  219.5820
# 2       Second Class  Corporate  United States  ...        2     0.00    6.8714
# 3     Standard Class   Consumer  United States  ...        5     0.45 -383.0310
# 4     Standard Class   Consumer  United States  ...        2     0.20    2.5164
# ...              ...        ...            ...  ...      ...      ...       ...
# 9989    Second Class   Consumer  United States  ...        3     0.20    4.1028
# 9990  Standard Class   Consumer  United States  ...        2     0.00   15.6332
# 9991  Standard Class   Consumer  United States  ...        2     0.20   19.3932
# 9992  Standard Class   Consumer  United States  ...        4     0.00   13.3200
# 9993    Second Class   Consumer  United States  ...        2     0.00   72.9480
#
# ...

# %% [markdown]
# **Let's find the corelation of the dataset.**

# %%
dataset.corr()
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales          -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity        0.012761  0.200795  1.000000  0.008623  0.066253
# Discount        0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit         -0.029961  0.479064  0.066253 -0.219487  1.000000

# %% [markdown]
# **Let's find the covariance of the data.**

# %%
dataset.cov()
# Out:
#               Postal Code          Sales    Quantity    Discount         Profit
# Postal Code  1.028080e+09 -476682.766590  910.415885  386.870404 -225045.849445
# Sales       -4.766828e+05  388434.455308  278.459923   -3.627228   69944.096586
# Quantity     9.104159e+02     278.459923    4.951113    0.003961      34.534769
# Discount     3.868704e+02      -3.627228    0.003961    0.042622     -10.615173
# Profit      -2.250458e+05   69944.096586   34.534769  -10.615173   54877.798055

# %% [markdown]
# **Let's find the series containing counts of unique values.**

# %%
dataset.value_counts()
# Out:
# Ship Mode       Segment      Country        City           State       Postal Code  Region   Category         Sub-Category  Sales    Quantity  Discount  Profit
# Second Class    Corporate    United States  Chicago        Illinois    60653        Central  Office Supplies  Binders       3.564    3         0.8       -6.2370     2
# Standard Class  Consumer     United States  Salem          Oregon      97301        West     Office Supplies  Paper         10.368   2         0.2        3.6288     2
#                                             San Francisco  California  94122        West     Office Supplies  Paper         12.840   3         0.0        5.7780     2
#                 Corporate    United States  Seattle        Washington  98105        West     Office Supplies  Paper         19.440   3         0.0        9.3312     2
# ...

# %% [markdown]
# **Deleting the variable.**

# %%
col=['Postal Code']
df=dataset.drop(columns=col,axis=1)

# %% [markdown]
# **Visualization of the given dataset**

# %%
plt.figure(figsize=(16,8))
plt.bar('Sub-Category','Category', data=dataset, color='maroon')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **Heatmap of the given dataset**

# %%
fig,axes = plt.subplots(1,1,figsize=(9,6))
sns.heatmap(dataset.corr(), annot= True,cmap='RdYlGn') #heatmap of corelation of data
plt.show()

# %%
fig,axes = plt.subplots(1,1,figsize=(9,6))
sns.heatmap(dataset.cov(), annot= True) #heatmap of covariance of the data
plt.show()

# %%
df['Ship Mode'].value_counts()
# Out:
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: Ship Mode, dtype: int64

# %%
sns.pairplot(df, hue = 'Ship Mode')

# %%
sns.countplot(x=df['Ship Mode'])

# %%
df['Segment'].value_counts()
# Out:
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: Segment, dtype: int64

# %%
sns.pairplot(df,hue='Segment')

# %%
sns.countplot(x=df['Segment'])

# %%
df['Category'].value_counts()
# Out:
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: Category, dtype: int64

# %%
sns.pairplot(df,hue='Category')

# %%
sns.countplot(x=df['Category'])

# %%
plt.figure(figsize=(10,18))
df['Sub-Category'].value_counts().plot.pie(autopct='%2f%%')
plt.show()

# %%
plt.figure(figsize=(15,12))
sns.countplot(x='State',data=df,palette='rainbow',order=df['State'].value_counts().index)
plt.xticks(rotation=90)
plt.show()

# %%
df1 = df.groupby('State')[['Sales','Profit']].sum().sort_values(by='Sales',ascending=False)
df1[:].plot.bar(color=['blue','orange','red'],figsize=(15,8))
plt.title('Profit/loss & Sales across states')
plt.xlabel('States')
plt.ylabel('Profit/loss & Sales')
plt.show()

# %%
df1 = df.groupby('Sub-Category')[['Sales','Profit']].sum().sort_values(by='Sales',ascending=False)
df1[:].plot.bar(color=['blue','red'],figsize=(15,8))
plt.title('Profit/loss & Sales across states')
plt.xlabel('Sub-Category')
plt.ylabel('Profit/loss & Sales')
plt.show()

# %%
df1 = df.groupby('Category')[['Sales','Profit']].sum().sort_values(by='Sales',ascending=False)
df1[:].plot.bar(color=['blue','red'],figsize=(15,8))
plt.title('Profit/loss & Sales of Diff Category')
plt.xlabel('Category')
plt.xticks(rotation=45)
plt.ylabel('Profit/loss & Sales')
plt.show()

# %%
df.groupby('Region')[['Profit','Sales']].sum().plot.bar(color=['pink','blue'],figsize=(8,5))
plt.ylabel('Profit/Loss and sales')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.title('Segment wise Sales in each Region')
sns.barplot(x='Region',y='Sales',data=df,hue='Segment',order=df['Region'].value_counts().index,palette='rainbow')
plt.xlabel('Region',fontsize=15)
plt.show()

# %%
x = sns.catplot(x="Sales", 
                y="Sub-Category",
                col="Category",
                data=df,
                kind='bar')

y = sns.catplot(x="Quantity", 
                y="Sub-Category",
                col="Category",
                data=df,
                kind='bar')

z = sns.catplot(x="Profit", 
                y="Sub-Category",
                col="Category",
                data=df,
                kind='bar')

# %% [markdown]
# **Conclusion**
#
#
# 1. From above graphs, we can conclude that
# * In technology category, Sales are more than other two category.
# * In technology category, Copiers and Machines are sold the most.
# * Quantity of products are almost sold in equal amount in each category.
# * In Furniture category, Bookcases and Tables are incurring a lose.
# * In Office Supplies category, there is a very minimal profit in all sub-categories.
# * In technology category, Copiers provide the most profit among all others.
#
# 2. California and New York have the highest profits while Texas,Ohio and Pennsylvania have the least profits.
#
# 3. Technology and Office Supplies have high profit.
# Furniture have less profit.
# 4. Profit and sales are maximum in west region and minimum in south region.
